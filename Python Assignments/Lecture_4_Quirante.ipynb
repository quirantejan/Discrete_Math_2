# %% [markdown]
# # Given the following graph, implement the algorithms in Python:
# ---
# $\textbf{1. Kruskal's Algorithm}$
#
# $\textbf{2. Prim's Algorithm}$
#
# $\textbf{3. Djitraka's Shortest Path Algorithm}$

# %%
import matplotlib.pyplot as plt
import networkx as nx
seed = 55
# Use seed for reproducibility
G = nx.Graph()
plt.figure(figsize=(10, 8))
# Add nodes
G.add_nodes_from(["A","B","C","D","E","F","G"])
# Add self-loops to the remaining nodes
edgelist = [("A","C"),("A","I"),("C","B"),("C","E"),("C","D"),("B","E"),("I","E"),("E","F"),("F","G"),("G","E")]
G.add_edges_from(edgelist)
pos = nx.planar_layout(G)  # Seed for reproducible layout
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels={("A","C"):10,("A","I"):5,("C","B"):20,("C","E"):15,("C","D"):30,("B","E"):25,("I","E"):40,("E","F"):35,("F","G"):50,("G","E"):45},
    font_color='red'
)
nx.draw(G, pos=pos,with_labels=True)
nx.draw(
    G, pos, edge_color='black', width=1, linewidths=1,
    node_size=500, node_color='pink', alpha=0.9,
    with_labels=True)

plt.show()

# %% [markdown]
# # Kruskal's Algorithm:
# ---

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create the graph
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G"])
edgelist = [("A", "C", 10), ("A", "I", 5), ("C", "B", 20), ("C", "E", 15),
            ("C", "D", 30), ("B", "E", 25), ("I", "E", 40), ("E", "F", 35),
            ("F", "G", 50), ("G", "E", 45)]
G.add_weighted_edges_from(edgelist)

# Apply Kruskal's algorithm to find the minimum spanning tree
T = nx.minimum_spanning_tree(G)

# Plot the minimum spanning tree
plt.figure(figsize=(10, 8))
nx.draw_networkx_edge_labels(T, pos, edge_labels={(u, v): d['weight'] for u, v, d in T.edges(data=True)}, font_color='red')
nx.draw(T, pos=pos, with_labels=True, node_size=500, node_color='pink', alpha=0.9, edge_color='black', width=1, linewidths=1)
plt.show()

# %% [markdown]
# # Prim's Algorithm:
# ---

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create the graph
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G"])
edgelist = [("A", "C", 10), ("A", "I", 5), ("C", "B", 20), ("C", "E", 15),
            ("C", "D", 30), ("B", "E", 25), ("I", "E", 40), ("E", "F", 35),
            ("F", "G", 50), ("G", "E", 45)]
G.add_weighted_edges_from(edgelist)

# Apply Prim's algorithm to find the minimum spanning tree
T = nx.minimum_spanning_tree(G, algorithm='prim')

# Plot the minimum spanning tree
plt.figure(figsize=(10, 8))
nx.draw_networkx_edge_labels(T, pos, edge_labels={(u, v): d['weight'] for u, v, d in T.edges(data=True)}, font_color='red')
nx.draw(T, pos=pos, with_labels=True, node_size=500, node_color='pink', alpha=0.9, edge_color='black', width=1, linewidths=1)
plt.show()

# %% [markdown]
# # Djitraka's Shortest Path Algorithm:
# ---

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create the graph
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G"])
edgelist = [("A", "C", 10), ("A", "I", 5), ("C", "B", 20), ("C", "E", 15),
            ("C", "D", 30), ("B", "E", 25), ("I", "E", 40), ("E", "F", 35),
            ("F", "G", 50), ("G", "E", 45)]
G.add_weighted_edges_from(edgelist)

# Apply Dijkstra's algorithm to find the shortest path from vertex "A" to all other vertices
shortest_paths = nx.single_source_dijkstra_path_length(G, source="A")

# Plot the original graph
plt.figure(figsize=(10, 8))
pos = nx.planar_layout(G)
nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): d['weight'] for u, v, d in G.edges(data=True)}, font_color='red')
nx.draw(G, pos=pos, with_labels=True, node_size=500, node_color='pink', alpha=0.9, edge_color='black', width=1, linewidths=1)
plt.title('Original Graph')
plt.show()

# Print the shortest paths from vertex "A" to all other vertices
print("Shortest Paths from vertex 'A':")
for vertex, distance in shortest_paths.items():
    print(f"Vertex: {vertex}, Distance from 'A': {distance}")
# Out:
# Shortest Paths from vertex 'A':
# Vertex: A, Distance from 'A': 0
# Vertex: I, Distance from 'A': 5
# Vertex: C, Distance from 'A': 10
# Vertex: E, Distance from 'A': 25
# Vertex: B, Distance from 'A': 30
# Vertex: D, Distance from 'A': 40
# Vertex: F, Distance from 'A': 60
# Vertex: G, Distance from 'A': 70

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create the graph
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G"])
edgelist = [("A", "C", 10), ("A", "I", 5), ("C", "B", 20), ("C", "E", 15),
            ("C", "D", 30), ("B", "E", 25), ("I", "E", 40), ("E", "F", 35),
            ("F", "G", 50), ("G", "E", 45)]
G.add_weighted_edges_from(edgelist)

# Calculate the shortest path from vertex "A" to all other vertices
shortest_paths = nx.single_source_dijkstra_path(G, source="A")

# Print the shortest paths
print("Shortest paths from vertex 'A':")
for target, path in shortest_paths.items():
    print(f"To {target}: {' -> '.join(path)}")

# Plot the graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=2000, node_color="skyblue", font_size=10, font_color="black")
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="red")
plt.show()
# Out:
# Shortest paths from vertex 'A':
# To A: A
# To C: A -> C
# To I: A -> I
# To E: A -> C -> E
# To B: A -> C -> B
# To D: A -> C -> D
# To F: A -> C -> E -> F
# To G: A -> C -> E -> G
